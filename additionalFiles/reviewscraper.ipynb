# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import calendar

# %%
#regex patterns
page_pat = re.compile(r'Page 1 of \d+')
review_pat = re.compile(r'<div class=\"review-data\">[;a-zA-Z\s,-.\'\/\?\[\]\":\']*</div>')
rating_pat = re.compile(r'Original Score:\s([A-Z](\+|-)?|\d(.\d)?(\/\d)?)')
fresh_pat = re.compile(r'small\s(fresh|rotten)\"')
#critic_pat = re.compile(r'\/\"\>([A-Z][a-zA-Z]+\s[A-Z][a-zA-Z\-]+)|([A-Z][a-zA-Z.]+\s[A-Z].?\s[A-Z][a-zA-Z]+)|([A-Z][a-zA-Z]+\s[A-Z]+\'[A-Z][a-zA-Z]+)')
critic_pat = re.compile(r'data-qa="review-critic-link".*?>(.|\n)*?</a>')
publisher_pat = re.compile(r'\"subtle\">[a-zA-Z\s,.\(\)\'\-&;!\/\d+]+</em>')
date_pat = re.compile(r'[a-zA-Z]+\s\d+,\s\d+')

# %%
def make_soup(url):
    try:
        r = requests.get(url)
        if r.status_code == 404:
            return ''
        soup = BeautifulSoup(r.content, 'html.parser')
    except requests.TooManyRedirects:
        soup = ''
    return soup

# %%
def get_num_pages(soup):
    match = re.findall(page_pat,str(list(soup)))
    print(match)
    if len(match) > 0:
        match = match[0]
        match = match.split(' of ')[-1]
        return match
    else:
        return None

# %%
def get_critic_reviews_from_page(soup):
    reviews = list()
    rating = list()
    fresh = list()
    critic = list()
    top_critic = list()
    publisher = list()
    date = list()
    
    soup = str(soup)
    review_soup = soup.split('="review_table')[1].split('<div class="review-row" data-qa="review-item" tabindex="0">\n')
    review_soup.pop(0)
    print(review_soup)

    for review in review_soup:
        # match = re.findall(review_pat, str(review))
        # print(len(match))
        # if len(match) > 0:
            # m = match[0]            
            # for iden in ['<div class="the_review" data-qa="review-item"> ','</div>']:
            #     m = m.replace(iden,'')
            # reviews.append(m.strip('"'))            
            # extract rating
            match = re.findall(rating_pat, str(review))
            if len(match) > 0:
                m = match[0][0]
                if '/1' in m:
                    sp_m = m.split('/')
                    if sp_m[-1] == '1':
                        sp_m[-1] = '10'
                    m = '/'.join(sp_m)
                rating.append(m)
            else:
                rating.append(None)                    
            # extract critic
            match = re.findall(critic_pat, str(review))
            print(str(review))
            print(match)
            if len(match) > 0:
                critic.append(''.join(match[0]))
            else:
                critic.append(None)            
            # check if top critic
            if '> Top Critic<' in str(review):
                top_critic.append(1)
            else:
                top_critic.append(0)            
            # extract publisher
            # match = re.findall(publisher_pat, str(review))
            # if len(match) > 0:
            #     m = match[0]
            #     m = m.replace('"subtle">', '')
            #     m = m.replace('</em>','')
            #     publisher.append(m)
            # else:
            #     publisher.append(None)            
            # extract date
            match = re.findall(date_pat, str(review))
            if len(match) > 0:
                date.append(match[0].strip('"'))
            else:
                date.append(None)
            
    return [reviews, rating, fresh, critic, top_critic, publisher, date]

# %%
def get_critic_reviews(page):
    info = [[],[],[],[],[],[],[]]
    soup = make_soup(page + "reviews")
#    print(soup)
    pages = get_num_pages(soup)
    print(pages)
    if pages is not None:
        for page_num in range(1,int(pages)+1):
            soup = make_soup(page + "reviews?page=" + str(page_num) + "&sort=")
            c_info = get_critic_reviews_from_page(soup)
            
            # accumulate review info
            for i in range(len(c_info)):
                info[i] = info[i] + c_info[i]
        
        c_info = dict()
        keys = ['reviews', 'rating', 'fresh', 'critic', 'top_critic', 'publisher', 'date']
        for k in range(len(keys)):
            c_info[keys[k]] = info[k]        
    else:
        c_info = None        
    return c_info

# %%
movie_df = pd.read_csv('movie_list.csv', delimiter=' ')
movie_list = movie_df['Title'].tolist()
print(movie_list)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather: Part II', '12 Angry Men', 'The Lord of the Rings: The Return of the King', 'Pulp Fiction', "Schindler's List", 'Inception', 'Fight Club', 'The Lord of the Rings: The Fellowship of the Ring', 'Forrest Gump', 'Il buono, il brutto, il cattivo', 'The Lord of the Rings: The Two Towers', 'The Matrix', 'Goodfellas', 'Star Wars: Episode V - The Empire Strikes Back', "One Flew Over the Cuckoo's Nest", 'Hamilton', 'Gisaengchung', 'Soorarai Pottru', 'Interstellar', 'Cidade de Deus', 'Sen to Chihiro no kamikakushi', 'Saving Private Ryan', 'The Green Mile', 'La vita è bella', 'Se7en', 'The Silence of the Lambs', 'Star Wars', 'Seppuku', 'Shichinin no samurai', "It's a Wonderful Life", 'Joker', 'Whiplash', 'The Intouchables', 'The Prestige', 'The Departed', 'The Pianist', 'Gladiator', 'American History X', 'The Usual Suspects', 'Léon', 'The Lion King', 'Terminator 2: Judgment Day', 'Nuovo Cinema Paradiso', 'Hotaru no haka', 'Back to the Future', 'Once Upon a Time in the West', 'Psycho', 'Casablanca', 'Modern Times', 'City Lights', 'Capharnaüm', 'Ayla: The Daughter of War', 'Vikram Vedha', 'Kimi no na wa.', 'Dangal', 'Spider-Man: Into the Spider-Verse', 'Avengers: Endgame', 'Avengers: Infinity War', 'Coco', 'Django Unchained', 'The Dark Knight Rises', '3 Idiots', 'Taare Zameen Par', 'WALL·E', 'The Lives of Others', 'Oldeuboi', 'Memento', 'Mononoke-hime', 'Once Upon a Time in America', 'Raiders of the Lost Ark', 'The Shining', 'Apocalypse Now', 'Alien', 'Anand', 'Tengoku to jigoku', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Witness for the Prosecution', 'Paths of Glory', 'Rear Window', 'Sunset Blvd.', 'The Great Dictator', '1917', 'Tumbbad', 'Andhadhun', 'Drishyam', 'Jagten', 'Jodaeiye Nader az Simin', 'Incendies', 'Miracle in cell NO.7', 'Babam ve Oglum', 'Inglourious Basterds', 'Eternal Sunshine of the Spotless Mind', 'Amélie', 'Snatch', 'Requiem for a Dream', 'American Beauty', 'Good Will Hunting', 'Bacheha-Ye aseman', 'Toy Story', 'Braveheart', 'Reservoir Dogs', 'Full Metal Jacket', 'Idi i smotri', 'Aliens', 'Amadeus', 'Scarface', 'Star Wars: Episode VI - Return of the Jedi', 'Das Boot', 'Taxi Driver', 'The Sting', 'A Clockwork Orange', '2001: A Space Odyssey', 'Per qualche dollaro in più', 'Lawrence of Arabia', 'The Apartment', 'North by Northwest', 'Vertigo', "Singin' in the Rain", 'Ikiru', 'Ladri di biciclette', 'Double Indemnity', 'Citizen Kane', 'M - Eine Stadt sucht einen Mörder', 'Metropolis', 'The Kid', 'Chhichhore', 'Uri: The Surgical Strike', 'K.G.F: Chapter 1', 'Green Book', 'Three Billboards Outside Ebbing, Missouri', 'Talvar', 'Baahubali 2: The Conclusion', 'Klaus', 'Drishyam', 'Queen', 'Mandariinid', 'Bhaag Milkha Bhaag', 'Gangs of Wasseypur', 'Udaan', 'Paan Singh Tomar', 'El secreto de sus ojos', 'Warrior', 'Shutter Island', 'Up', 'The Wolf of Wall Street', 'Chak De! India', 'There Will Be Blood', "Pan's Labyrinth", 'Toy Story 3', 'V for Vendetta', 'Rang De Basanti', 'Black', 'Batman Begins', 'Swades: We, the People', 'Der Untergang', 'Hauru no ugoku shiro', 'A Beautiful Mind', 'Hera Pheri', 'Lock, Stock and Two Smoking Barrels', 'L.A. Confidential', 'Eskiya', 'Heat', 'Casino', 'Andaz Apna Apna', 'Unforgiven', 'Indiana Jones and the Last Crusade', 'Dom za vesanje', 'Tonari no Totoro', 'Die Hard', 'Ran', 'Raging Bull', 'Stalker', 'Höstsonaten', 'The Message', 'Sholay', 'Monty Python and the Holy Grail', 'The Great Escape', 'To Kill a Mockingbird', 'Yôjinbô', 'Judgment at Nuremberg', 'Some Like It Hot', 'Smultronstället', 'Det sjunde inseglet', 'Du rififi chez les hommes', 'Dial M for Murder', 'Tôkyô monogatari', 'Rashômon', 'All About Eve', 'The Treasure of the Sierra Madre', 'To Be or Not to Be', 'The Gold Rush', 'Sherlock Jr.', 'Portrait de la jeune fille en feu', 'Pink', 'Koe no katachi', 'Contratiempo', 'Ah-ga-ssi', 'Mommy', 'Haider', 'Logan', 'Room', 'Relatos salvajes', 'Soul', 'Kis Uykusu', 'PK', 'OMG: Oh My G ...

# %%
movies = [m.replace(' ', '_') for m in movie_list]


movie = list()
critic = list()
publisher = list()
rating = list()
date = list()
comment = list()

count = 0

for movie_name in movies:
    count += 1
    print(count)
    url = f'https://www.rottentomatoes.com/m/{movie_name}/' + "reviews"
    soup = make_soup(url)
    if soup == '':
        # print("Soup not found")
        continue
    
    print(url)

    review_list = list()
    for r in soup.find_all("div", "review-row"):
        review_list.append(r)

    for review in review_list:
        #Get Critic Name
        try:
            critic.append(review.find_all("a", "display-name")[0].get_text().strip())
        except:
            continue
        #Get Publisher Name
        try:
            publisher.append(review.find_all("a", "publication")[0].get_text().strip())
        except:
            critic.pop()
            continue
        #Get Rating
        #Get Date
        try:
            rating_text = review.find_all("p", "original-score-and-url")[0].get_text().strip()
        except:
            critic.pop()
            publisher.pop()
            continue
        rating_text = rating_text.split('Original Score: ')
        if len(rating_text) > 1:
            rating.append(rating_text[1].split('\n')[0])
            date.append(rating_text[1].split('| ')[1])
        else:
            rating.append(None)
            date.append(rating_text[0].split('| ')[1])
        #Get Comment
        try:
            comment.append(review.find_all("p", "review-text")[0].get_text().strip())
        except:
            critic.pop()
            publisher.pop()
            rating.pop()
            date.pop()
            continue
        #Append Movie Name
        movie.append(movie_name.replace('_', ' '))

frame = {"movie_name": movie, "critic_name": critic, "publisher": publisher, "rating": rating, "date": date, "comment": comment}

df = pd.DataFrame.from_dict(frame)
# Out:
# 1
# https://www.rottentomatoes.com/m/The_Shawshank_Redemption/reviews
# 2
# https://www.rottentomatoes.com/m/The_Godfather/reviews
# 3
# https://www.rottentomatoes.com/m/The_Dark_Knight/reviews
# 4
# 5
# 6
# 7
# https://www.rottentomatoes.com/m/Pulp_Fiction/reviews
# 8
# 9
# https://www.rottentomatoes.com/m/Inception/reviews
# 10
# https://www.rottentomatoes.com/m/Fight_Club/reviews
# 11
# 12
# https://www.rottentomatoes.com/m/Forrest_Gump/reviews
# 13
# 14
# 15
# https://www.rottentomatoes.com/m/The_Matrix/reviews
# 16
# https://www.rottentomatoes.com/m/Goodfellas/reviews
# 17
# 18
# 19
# 20
# 21
# https://www.rottentomatoes.com/m/Soorarai_Pottru/reviews
# 22
# https://www.rottentomatoes.com/m/Interstellar/reviews
# 23
# 24
# https://www.rottentomatoes.com/m/Sen_to_Chihiro_no_kamikakushi/reviews
# 25
# https://www.rottentomatoes.com/m/Saving_Private_Ryan/reviews
# 26
# https://www.rottentomatoes.com/m/The_Green_Mile/reviews
# 27
# 28
# 29
# https://www.rottentomatoes.com/m/The_Silence_of_the_Lambs/reviews
# 30
# https://www.rottentomatoes.com/m/Star_Wars/reviews
# 31
# https://www.rottentomatoes.com/m/Seppuku/reviews
# 32
# 33
# 34
# https://www.rottentomatoes.com/m/Joker/reviews
# 35
# https://www.rottentomatoes.com/m/Whiplash/reviews
# 36
# https://www.rottentomatoes.com/m/The_Intouchables/reviews
# 37
# 38
# https://www.rottentomatoes.com/m/The_Departed/reviews
# 39
# https://www.rottentomatoes.com/m/The_Pianist/reviews
# 40
# https://www.rottentomatoes.com/m/Gladiator/reviews
# 41
# https://www.rottentomatoes.com/m/American_History_X/reviews
# 42
# 43
# 44
# https://www.rottentomatoes.com/m/The_Lion_King/reviews
# 45
# 46
# 47
# https://www.rottentomatoes.com/m/Hotaru_no_haka/reviews
# 48
# https://www.rottentomatoes.com/m/Back_to_the_Future/reviews
# 49
# https://www.rottentomatoes.com/m/Once_Upon_a_Time_in_the_West/reviews
# 50
# https://www.rottentomatoes.com/m/Psycho/reviews
# 51
# https://www.rottentomatoes.com/m/Casablanca/reviews
# 52
# https://www.rottentomatoes.com/m/Modern_Times/reviews
# 53
# https://www.rottentomatoes.com/m/City_Lights/reviews
# 54
# 55
# 56
# https://www.rottentomatoes.com/m/Vikram_Vedha/reviews
# 57
# 58
# https://www.rottentomatoes.com/m/Dangal/reviews
# 59
# 60
# 61
# 62
# https://www.rottentomatoes.com/m/Coco/reviews
# 63
# https://www.rottentomatoes.com/m/Django_Unchained/reviews
# 64
# https://www.rottentomatoes.com/m/The_Dark_Knight_Rises/reviews
# 65
# https://www.rottentomatoes.com/m/3_Idiots/reviews
# https://www.rottentomatoes.com/m/The_Imitation_Game/reviews
# 340
# https://www.rottentomatoes.com/m/Guardians_of_the_Galaxy/reviews
# 341
# https://www.rottentomatoes.com/m/Blade_Runner_2049/reviews
# 342
# https://www.rottentomatoes.com/m/Her/reviews
# 343
# https://www.rottentomatoes.com/m/Bohemian_Rhapsody/reviews
# 344
# 345
# https://www.rottentomatoes.com/m/The_Perks_of_Being_a_Wallflower/reviews
# 346
# 347
# 348
# https://www.rottentomatoes.com/m/The_Help/reviews
# 349
# https://www.rottentomatoes.com/m/Deadpool/reviews
# 350
# https://www.rottentomatoes.com/m/Darbareye_Elly/reviews
# 351
# 352
# 353
# https://www.rottentomatoes.com/m/My_Name_Is_Khan/reviews
# 354
# 355
# https://www.rottentomatoes.com/m/Slumdog_Millionaire/reviews
# 356
# https://www.rottentomatoes.com/m/Black_Swan/reviews
# 357
# https://www.rottentomatoes.com/m/Tropa_de_Elite/reviews
# 358
# 359
# https://www.rottentomatoes.com/m/Persepolis/reviews
# 360
# https://www.rottentomatoes.com/m/Dallas_Buyers_Club/reviews
# 361
# 362
# https://www.rottentomatoes.com/m/Blood_Diamond/reviews
# 363
# 364
# 365
# https://www.rottentomatoes.com/m/Sin_City/reviews
# 366
# 367
# 368
# https://www.rottentomatoes.com/m/Ratatouille/reviews
# 369
# https://www.rottentomatoes.com/m/Casino_Royale/reviews
# 370
# 371
# 372
# 373
# 374
# https://www.rottentomatoes.com/m/Cinderella_Man/reviews
# 375
# 376
# 377
# 378
# 379
# https://www.rottentomatoes.com/m/The_Incredibles/reviews
# 380
# 381
# https://www.rottentomatoes.com/m/Dogville/reviews
# 382
# https://www.rottentomatoes.com/m/Vizontele/reviews
# 383
# https://www.rottentomatoes.com/m/Donnie_Darko/reviews
# 384
# https://www.rottentomatoes.com/m/Magnolia/reviews
# 385
# https://www.rottentomatoes.com/m/Dancer_in_the_Dark/reviews
# 386
# 387
# 388
# 389
# 390
# https://www.rottentomatoes.com/m/The_Iron_Giant/reviews
# 391
# 392
# https://www.rottentomatoes.com/m/Sling_Blade/reviews
# 393
# 394
# 395
# 396
# 397
# https://www.rottentomatoes.com/m/Groundhog_Day/reviews
# 398
# https://www.rottentomatoes.com/m/Bound_by_Honor/reviews
# 399
# 400
# https://www.rottentomatoes.com/m/Aladdin/reviews
# 401
# 402
# https://www.rottentomatoes.com/m/Beauty_and_the_Beast/reviews
# 403
# https://www.rottentomatoes.com/m/Dances_with_Wolves/reviews
# 404
# https://www.rottentomatoes.com/m/Do_the_Right_Thing/reviews
# 405
# https://www.rottentomatoes.com/m/Rain_Man/reviews
# 406
# https://www.rottentomatoes.com/m/Akira/reviews
# 407
# https://www.rottentomatoes.com/m/The_Princess_Bride/reviews
# 408
# 409
# https://www.rottentomatoes.com/m/Au_revoir_les_enfants/reviews
# 410
# 411
# https://www.rottentomatoes.com/m/The_Terminator/reviews
# 412
# https://www.rottentomatoes.com/m/Gandhi/reviews
# 413
# 478
# 479
# https://www.rottentomatoes.com/m/Before_Midnight/reviews
# 480
# 481
# 482
# https://www.rottentomatoes.com/m/The_Artist/reviews
# 483
# https://www.rottentomatoes.com/m/Edge_of_Tomorrow/reviews
# 484
# 485
# https://www.rottentomatoes.com/m/The_Irishman/reviews
# 486
# 487
# https://www.rottentomatoes.com/m/Moon/reviews
# 488
# 489
# https://www.rottentomatoes.com/m/District_9/reviews
# 490
# https://www.rottentomatoes.com/m/The_Wrestler/reviews
# 491
# https://www.rottentomatoes.com/m/Jab_We_Met/reviews
# 492
# https://www.rottentomatoes.com/m/Boyhood/reviews
# 493
# 494
# https://www.rottentomatoes.com/m/Star_Trek/reviews
# 495
# https://www.rottentomatoes.com/m/In_Bruges/reviews
# 496
# https://www.rottentomatoes.com/m/The_Man_from_Earth/reviews
# 497
# https://www.rottentomatoes.com/m/Letters_from_Iwo_Jima/reviews
# 498
# https://www.rottentomatoes.com/m/The_Fall/reviews
# 499
# https://www.rottentomatoes.com/m/Life_of_Pi/reviews
# 500
# 501
# 502
# 503
# https://www.rottentomatoes.com/m/Iron_Man/reviews
# 504
# https://www.rottentomatoes.com/m/Shaun_of_the_Dead/reviews
# 505
# 506
# https://www.rottentomatoes.com/m/Mystic_River/reviews
# 507
# https://www.rottentomatoes.com/m/Harry_Potter_and_the_Prisoner_of_Azkaban/reviews
# 508
# 509
# 510
# 511
# 512
# 513
# https://www.rottentomatoes.com/m/Nueve_reinas/reviews
# 514
# https://www.rottentomatoes.com/m/Children_of_Men/reviews
# 515
# https://www.rottentomatoes.com/m/Almost_Famous/reviews
# 516
# 517
# https://www.rottentomatoes.com/m/Toy_Story_2/reviews
# 518
# https://www.rottentomatoes.com/m/Boogie_Nights/reviews
# 519
# 520
# https://www.rottentomatoes.com/m/Once_Were_Warriors/reviews
# 521
# https://www.rottentomatoes.com/m/True_Romance/reviews
# 522
# 523
# 524
# 525
# https://www.rottentomatoes.com/m/Edward_Scissorhands/reviews
# 526
# 527
# https://www.rottentomatoes.com/m/Crimes_and_Misdemeanors/reviews
# 528
# 529
# https://www.rottentomatoes.com/m/Hannah_and_Her_Sisters/reviews
# 530
# https://www.rottentomatoes.com/m/Brazil/reviews
# 531
# https://www.rottentomatoes.com/m/This_Is_Spinal_Tap/reviews
# 532
# 533
# https://www.rottentomatoes.com/m/The_Blues_Brothers/reviews
# 534
# https://www.rottentomatoes.com/m/Manhattan/reviews
# 535
# https://www.rottentomatoes.com/m/All_That_Jazz/reviews
# 536
# https://www.rottentomatoes.com/m/Dawn_of_the_Dead/reviews
# 537
# 538
# 539
# https://www.rottentomatoes.com/m/Amarcord/reviews
# 540
# 541
# 542
# https://www.rottentomatoes.com/m/Harold_and_Maude/reviews
# 543
# https://www.rottentomatoes.com/m/Patton/reviews
# 544
# https://www.rottentomatoes.com/m/The_Wild_Bunch/reviews
# 545
# https://www.rottentomatoes.com/m/Night_of_the_Living_Dead/reviews
# 546
# 678
# https://www.rottentomatoes.com/m/Predator/reviews
# 679
# 680
# 681
# https://www.rottentomatoes.com/m/Down_by_Law/reviews
# 682
# https://www.rottentomatoes.com/m/The_Goonies/reviews
# 683
# https://www.rottentomatoes.com/m/The_Color_Purple/reviews
# 684
# 685
# https://www.rottentomatoes.com/m/The_Killing_Fields/reviews
# 686
# https://www.rottentomatoes.com/m/Ghostbusters/reviews
# 687
# https://www.rottentomatoes.com/m/The_Right_Stuff/reviews
# 688
# 689
# 690
# 691
# https://www.rottentomatoes.com/m/Days_of_Heaven/reviews
# 692
# https://www.rottentomatoes.com/m/The_Outlaw_Josey_Wales/reviews
# 693
# 694
# https://www.rottentomatoes.com/m/The_Conversation/reviews
# 695
# 696
# 697
# https://www.rottentomatoes.com/m/Badlands/reviews
# 698
# https://www.rottentomatoes.com/m/Cabaret/reviews
# 699
# 700
# https://www.rottentomatoes.com/m/Midnight_Cowboy/reviews
# 701
# https://www.rottentomatoes.com/m/Wait_Until_Dark/reviews
# 702
# 703
# https://www.rottentomatoes.com/m/Bonnie_and_Clyde/reviews
# 704
# https://www.rottentomatoes.com/m/My_Fair_Lady/reviews
# 705
# https://www.rottentomatoes.com/m/Mary_Poppins/reviews
# 706
# https://www.rottentomatoes.com/m/The_Longest_Day/reviews
# 707
# 708
# https://www.rottentomatoes.com/m/The_Innocents/reviews
# 709
# 710
# https://www.rottentomatoes.com/m/Red_River/reviews
# 711
# https://www.rottentomatoes.com/m/Key_Largo/reviews
# 712
# https://www.rottentomatoes.com/m/To_Have_and_Have_Not/reviews
# 713
# 714
# https://www.rottentomatoes.com/m/Stagecoach/reviews
# 715
# 716
# https://www.rottentomatoes.com/m/Bringing_Up_Baby/reviews
# 717
# https://www.rottentomatoes.com/m/Bride_of_Frankenstein/reviews
# 718
# https://www.rottentomatoes.com/m/Duck_Soup/reviews
# 719
# 720
# https://www.rottentomatoes.com/m/Frankenstein/reviews
# 721
# https://www.rottentomatoes.com/m/Roma/reviews
# 722
# 723
# https://www.rottentomatoes.com/m/Deadpool_2/reviews
# 724
# https://www.rottentomatoes.com/m/Wind_River/reviews
# 725
# https://www.rottentomatoes.com/m/Get_Out/reviews
# 726
# 727
# 728
# https://www.rottentomatoes.com/m/What_We_Do_in_the_Shadows/reviews
# 729
# 730
# 731
# 732
# https://www.rottentomatoes.com/m/The_Fault_in_Our_Stars/reviews
# 733
# https://www.rottentomatoes.com/m/Me_and_Earl_and_the_Dying_Girl/reviews
# 734
# 735
# 736
# 737
# https://www.rottentomatoes.com/m/The_Broken_Circle_Breakdown/reviews
# 738
# 739
# https://www.rottentomatoes.com/m/Rockstar/reviews
# 740
# https://www.rottentomatoes.com/m/Nebraska/reviews
# 741
# 742
# 743
# https://www.rottentomatoes.com/m/Detachment/reviews
# 744
# https://www.rottentomatoes.com/m/Midnight_in_Paris/reviews
# 745
# https://www.rottentomatoes.com/m/The_Lego_Movie/reviews
# 746
# https://www.rottentomatoes.com/m/Gravity/reviews
# 747
# https://www.rottentomatoes.com/m/Star_Trek_Into_Darkness/reviews
# 748
# https://www.rottentomatoes.com/m/Beasts_of_No_Nation/reviews
# 749
# https://www.rottentomatoes.com/m/The_Social_Network/reviews
# 750
# 751
# https://www.rottentomatoes.com/m/The_Hangover/reviews
# 752
# https://www.rottentomatoes.com/m/Skyfall/reviews
# 753
# https://www.rottentomatoes.com/m/Silver_Linings_Playbook/reviews
# 754
# 755
# 756
# 757
# 758
# 759
# 760
# https://www.rottentomatoes.com/m/Changeling/reviews
# 761
# https://www.rottentomatoes.com/m/Flipped/reviews
# 762
# 763
# 764
# https://www.rottentomatoes.com/m/This_Is_England/reviews
# 765
# https://www.rottentomatoes.com/m/Ex_Machina/reviews
# 766
# 767
# https://www.rottentomatoes.com/m/The_Last_King_of_Scotland/reviews
# 768
# https://www.rottentomatoes.com/m/Zodiac/reviews
# 769
# https://www.rottentomatoes.com/m/Lucky_Number_Slevin/reviews
# 770
# 771
# https://www.rottentomatoes.com/m/Control/reviews
# 772
# https://www.rottentomatoes.com/m/Tangled/reviews
# 773
# 774
# https://www.rottentomatoes.com/m/Brokeback_Mountain/reviews
# 775
# 776
# https://www.rottentomatoes.com/m/Crash/reviews
# 777
# 778
# 779
# https://www.rottentomatoes.com/m/The_Machinist/reviews
# 780
# https://www.rottentomatoes.com/m/Ray/reviews
# 781
# https://www.rottentomatoes.com/m/Lost_in_Translation/reviews
# 782
# https://www.rottentomatoes.com/m/Harry_Potter_and_the_Goblet_of_Fire/reviews
# 783
# https://www.rottentomatoes.com/m/Man_on_Fire/reviews
# 784
# https://www.rottentomatoes.com/m/Coraline/reviews
# 785
# 786
# 787
# 788
# https://www.rottentomatoes.com/m/In_America/reviews
# 789
# https://www.rottentomatoes.com/m/I_Am_Sam/reviews
# 790
# 791
# https://www.rottentomatoes.com/m/Black_Hawk_Down/reviews
# 792
# https://www.rottentomatoes.com/m/Road_to_Perdition/reviews
# 793
# 794
# https://www.rottentomatoes.com/m/Billy_Elliot/reviews
# 795
# https://www.rottentomatoes.com/m/Hedwig_and_the_Angry_Inch/reviews
# 796
# 797
# 798
# 799
# 800
# 801
# https://www.rottentomatoes.com/m/Office_Space/reviews
# 802
# https://www.rottentomatoes.com/m/Happiness/reviews
# 803
# https://www.rottentomatoes.com/m/Training_Day/reviews
# 804
# https://www.rottentomatoes.com/m/Rushmore/reviews
# 805
# https://www.rottentomatoes.com/m/Abre_los_ojos/reviews
# 806
# https://www.rottentomatoes.com/m/Being_John_Malkovich/reviews
# 807
# https://www.rottentomatoes.com/m/As_Good_as_It_Gets/reviews
# 808
# https://www.rottentomatoes.com/m/The_Fifth_Element/reviews
# 809
# 810
# https://www.rottentomatoes.com/m/Donnie_Brasco/reviews
# 811
# https://www.rottentomatoes.com/m/Shine/reviews
# 812
# 813
# https://www.rottentomatoes.com/m/Hamlet/reviews
# 814
# https://www.rottentomatoes.com/m/A_Little_Princess/reviews
# 815
# 816
# https://www.rottentomatoes.com/m/Il_postino/reviews
# 817
# https://www.rottentomatoes.com/m/Clerks/reviews
# 818
# https://www.rottentomatoes.com/m/Short_Cuts/reviews
# 819
# https://www.rottentomatoes.com/m/Philadelphia/reviews
# 820
# 821
# 822
# https://www.rottentomatoes.com/m/The_Last_of_the_Mohicans/reviews
# 823
# 824
# https://www.rottentomatoes.com/m/Glengarry_Glen_Ross/reviews
# 825
# 826
# https://www.rottentomatoes.com/m/Fried_Green_Tomatoes/reviews
# 827
# https://www.rottentomatoes.com/m/Barton_Fink/reviews
# 828
# 829
# https://www.rottentomatoes.com/m/Who_Framed_Roger_Rabbit/reviews
# 830
# 831
# 832
# 833
# https://www.rottentomatoes.com/m/Empire_of_the_Sun/reviews
# 834
# 835
# https://www.rottentomatoes.com/m/Blue_Velvet/reviews
# 836
# 837
# https://www.rottentomatoes.com/m/After_Hours/reviews
# 838
# https://www.rottentomatoes.com/m/Zelig/reviews
# 839
# https://www.rottentomatoes.com/m/The_Verdict/reviews
# 840
# 841
# https://www.rottentomatoes.com/m/First_Blood/reviews
# 842
# https://www.rottentomatoes.com/m/Ordinary_People/reviews
# 843
# 844
# 845
# 846
# https://www.rottentomatoes.com/m/Le_locataire/reviews
# 847
# https://www.rottentomatoes.com/m/Love_and_Death/reviews
# 848
# https://www.rottentomatoes.com/m/The_Taking_of_Pelham_One_Two_Three/reviews
# 849
# https://www.rottentomatoes.com/m/Blazing_Saddles/reviews
# 850
# https://www.rottentomatoes.com/m/Serpico/reviews
# 851
# https://www.rottentomatoes.com/m/Enter_the_Dragon/reviews
# 852
# https://www.rottentomatoes.com/m/Deliverance/reviews
# 853
# https://www.rottentomatoes.com/m/The_French_Connection/reviews
# 854
# https://www.rottentomatoes.com/m/Dirty_Harry/reviews
# 855
# https://www.rottentomatoes.com/m/Where_Eagles_Dare/reviews
# 856
# https://www.rottentomatoes.com/m/The_Odd_Couple/reviews
# 857
# https://www.rottentomatoes.com/m/The_Dirty_Dozen/reviews
# 858
# https://www.rottentomatoes.com/m/Belle_de_jour/reviews
# 859
# https://www.rottentomatoes.com/m/A_Man_for_All_Seasons/reviews
# 860
# https://www.rottentomatoes.com/m/Repulsion/reviews
# 861
# https://www.rottentomatoes.com/m/Zulu/reviews
# 862
# https://www.rottentomatoes.com/m/Goldfinger/reviews
# 863
# 864
# 865
# https://www.rottentomatoes.com/m/Peeping_Tom/reviews
# 866
# https://www.rottentomatoes.com/m/The_Magnificent_Seven/reviews
# 867
# https://www.rottentomatoes.com/m/Les_yeux_sans_visage/reviews
# 868
# 869
# https://www.rottentomatoes.com/m/Rebel_Without_a_Cause/reviews
# 870
# 871
# https://www.rottentomatoes.com/m/Sabrina/reviews
# 872
# 873
# 874
# https://www.rottentomatoes.com/m/The_African_Queen/reviews
# 875
# https://www.rottentomatoes.com/m/Gilda/reviews
# 876
# https://www.rottentomatoes.com/m/Fantasia/reviews
# 877
# https://www.rottentomatoes.com/m/The_Invisible_Man/reviews
# 878
# https://www.rottentomatoes.com/m/Dark_Waters/reviews
# 879
# 880
# 881
# 882
# https://www.rottentomatoes.com/m/The_Florida_Project/reviews
# 883
# https://www.rottentomatoes.com/m/Just_Mercy/reviews
# 884
# https://www.rottentomatoes.com/m/Gifted/reviews
# 885
# https://www.rottentomatoes.com/m/The_Peanut_Butter_Falcon/reviews
# 886
# https://www.rottentomatoes.com/m/Victoria/reviews
# 887
# https://www.rottentomatoes.com/m/Mustang/reviews
# 888
# 889
# https://www.rottentomatoes.com/m/Baby_Driver/reviews
# 890
# https://www.rottentomatoes.com/m/Only_the_Brave/reviews
# 891
# https://www.rottentomatoes.com/m/Bridge_of_Spies/reviews
# 892
# https://www.rottentomatoes.com/m/Incredibles_2/reviews
# 893
# https://www.rottentomatoes.com/m/Moana/reviews
# 894
# https://www.rottentomatoes.com/m/Sicario/reviews
# 895
# https://www.rottentomatoes.com/m/Creed/reviews
# 896
# https://www.rottentomatoes.com/m/Leviafan/reviews
# 897
# https://www.rottentomatoes.com/m/Hell_or_High_Water/reviews
# 898
# https://www.rottentomatoes.com/m/Philomena/reviews
# 899
# https://www.rottentomatoes.com/m/Dawn_of_the_Planet_of_the_Apes/reviews
# 900
# https://www.rottentomatoes.com/m/El_cuerpo/reviews
# 901
# 902
# https://www.rottentomatoes.com/m/End_of_Watch/reviews
# 903
# 904
# https://www.rottentomatoes.com/m/A_Star_Is_Born/reviews
# 905
# https://www.rottentomatoes.com/m/True_Grit/reviews
# 906
# 907
# https://www.rottentomatoes.com/m/Despicable_Me/reviews
# 908
# 909
# 910
# 911
# https://www.rottentomatoes.com/m/Moneyball/reviews
# 912
# https://www.rottentomatoes.com/m/La_piel_que_habito/reviews
# 913
# https://www.rottentomatoes.com/m/Zombieland/reviews
# 914
# https://www.rottentomatoes.com/m/Die_Welle/reviews
# 915
# https://www.rottentomatoes.com/m/Sherlock_Holmes/reviews
# 916
# https://www.rottentomatoes.com/m/The_Blind_Side/reviews
# 917
# https://www.rottentomatoes.com/m/The_Visitor/reviews
# 918
# https://www.rottentomatoes.com/m/Seven_Pounds/reviews
# 919
# https://www.rottentomatoes.com/m/Eastern_Promises/reviews
# 920
# https://www.rottentomatoes.com/m/Stardust/reviews
# 921
# https://www.rottentomatoes.com/m/The_Secret_of_Kells/reviews
# 922
# https://www.rottentomatoes.com/m/Inside_Man/reviews
# 923
# https://www.rottentomatoes.com/m/Gone_Baby_Gone/reviews
# 924
# https://www.rottentomatoes.com/m/La_Vie_En_Rose/reviews
# 925
# 926
# https://www.rottentomatoes.com/m/The_Illusionist/reviews
# 927
# 928
# 929
# https://www.rottentomatoes.com/m/300/reviews
# 930
# https://www.rottentomatoes.com/m/Match_Point/reviews
# 931
# https://www.rottentomatoes.com/m/Watchmen/reviews
# 932
# https://www.rottentomatoes.com/m/Lord_of_War/reviews
# 933
# https://www.rottentomatoes.com/m/Saw/reviews
# 934
# 935
# https://www.rottentomatoes.com/m/Mysterious_Skin/reviews
# 936
# 937
# 938
# 939
# https://www.rottentomatoes.com/m/21_Grams/reviews
# 940
# 941
# https://www.rottentomatoes.com/m/Finding_Neverland/reviews
# 942
# https://www.rottentomatoes.com/m/25th_Hour/reviews
# 943
# 944
# 945
# 946
# https://www.rottentomatoes.com/m/The_Royal_Tenenbaums/reviews
# 947
# 948
# 949
# https://www.rottentomatoes.com/m/The_Others/reviews
# 950
# https://www.rottentomatoes.com/m/Blow/reviews
# 951
# https://www.rottentomatoes.com/m/Enemy_at_the_Gates/reviews
# 952
# https://www.rottentomatoes.com/m/Minority_Report/reviews
# 953
# https://www.rottentomatoes.com/m/The_Hurricane/reviews
# 954
# https://www.rottentomatoes.com/m/American_Psycho/reviews
# 955
# 956
# 957
# https://www.rottentomatoes.com/m/Mulan/reviews
# 958
# https://www.rottentomatoes.com/m/Fear_and_Loathing_in_Las_Vegas/reviews
# 959
# 960
# https://www.rottentomatoes.com/m/Dark_City/reviews
# 961
# 962
# https://www.rottentomatoes.com/m/Lost_Highway/reviews
# 963
# https://www.rottentomatoes.com/m/Sense_and_Sensibility/reviews
# 964
# 965
# https://www.rottentomatoes.com/m/Dead_Man/reviews
# 966
# 967
# https://www.rottentomatoes.com/m/Apollo_13/reviews
# 968
# 969
# https://www.rottentomatoes.com/m/Falling_Down/reviews
# 970
# https://www.rottentomatoes.com/m/Dazed_and_Confused/reviews
# 971
# https://www.rottentomatoes.com/m/My_Cousin_Vinny/reviews
# 972
# https://www.rottentomatoes.com/m/Omohide_poro_poro/reviews
# 973
# https://www.rottentomatoes.com/m/Delicatessen/reviews
# 974
# https://www.rottentomatoes.com/m/Home_Alone/reviews
# 975
# 976
# 977
# https://www.rottentomatoes.com/m/The_Little_Mermaid/reviews
# 978
# 979
# 980
# https://www.rottentomatoes.com/m/Lethal_Weapon/reviews
# 981
# https://www.rottentomatoes.com/m/Blood_Simple/reviews
# 982
# https://www.rottentomatoes.com/m/On_Golden_Pond/reviews
# 983
# 984
# https://www.rottentomatoes.com/m/The_Warriors/reviews
# 985
# https://www.rottentomatoes.com/m/The_Muppet_Movie/reviews
# 986
# https://www.rottentomatoes.com/m/Escape_from_Alcatraz/reviews
# 987
# https://www.rottentomatoes.com/m/Watership_Down/reviews
# 988
# https://www.rottentomatoes.com/m/Midnight_Express/reviews
# 989
# https://www.rottentomatoes.com/m/Close_Encounters_of_the_Third_Kind/reviews
# 990
# https://www.rottentomatoes.com/m/The_Long_Goodbye/reviews
# 991
# 992
# 993
# https://www.rottentomatoes.com/m/The_Jungle_Book/reviews
# 994
# https://www.rottentomatoes.com/m/Blowup/reviews
# 995
# 996
# 997
# https://www.rottentomatoes.com/m/Giant/reviews
# 998
# https://www.rottentomatoes.com/m/From_Here_to_Eternity/reviews
# 999
# https://www.rottentomatoes.com/m/Lifeboat/reviews
# 1000

# %%
display(df)
# Out:
#                     movie_name          critic_name  \
# 0     The Shawshank Redemption      Jonathan Romney
# 1     The Shawshank Redemption            Jay Boyar
# 2     The Shawshank Redemption      Adam Mars-Jones
# 3     The Shawshank Redemption      Malcolm Johnson
# 4     The Shawshank Redemption         Yardena Arar
# ...                        ...                  ...
# 9941                  Lifeboat      Bosley Crowther
# 9942                  Lifeboat  Jeffrey M. Anderson
# 9943                  Lifeboat        Philip Martin
# 9944                  Lifeboat         Dan Callahan
# 9945                  Lifeboat           Jay Antani
#
#                       publisher rating          date  \
# 0                      Guardian   None   Mar 4, 2024
# 1              Orlando Sentinel   None   Mar 4, 2024
# 2              Independent (UK)   None   Mar 4, 2024
# 3              Hartford Courant  3.5/4   Mar 4, 2024
# 4        Los Angeles Daily News   None   Mar 4, 2024
# ...                         ...    ...           ...
# 9941             New York Times    4/5  Mar 25, 2006
# 9942      Combustible Celluloid  3.5/4  Dec 17, 2005
# 9943  Arkansas Democrat-Gazette    3/5   Nov 7, 2005
# 9944             Slant Magazine    4/4  Oct 24, 2005
# 9945             Filmcritic.com    4/5  Oct 21, 2005
#
#                                                 comment
# 0     If this is a feel-good movie -- and by the end...
# 1     The Shawshank Redemption is both resigned and ...
# 2     The sad thing is that The Shawshank Redemption...
# 3     Next to Stand By Me, The Shawshank Redemption ...
# 4     It's Robbins and Freeman who carry the film, w...
# ...                                                 ...
# 9941  That old master of screen melodrama, Alfred Hi...
# 9942                    It's a technical tour-de-force.
# 9943
# 9944  Hitchcock's shifting sympathies guarantee our ...
# 9945  boasts the filmmaker's trademark technical pol...
#
# [9946 rows x 6 columns]

# %%
new_df = df.dropna()

# %%
display(new_df)
# Out:
#                     movie_name          critic_name  \
# 3     The Shawshank Redemption      Malcolm Johnson
# 6     The Shawshank Redemption       William Arnold
# 9     The Shawshank Redemption   Michael Wilmington
# 12    The Shawshank Redemption           Jeff Simon
# 14    The Shawshank Redemption         Jack Mathews
# ...                        ...                  ...
# 9941                  Lifeboat      Bosley Crowther
# 9942                  Lifeboat  Jeffrey M. Anderson
# 9943                  Lifeboat        Philip Martin
# 9944                  Lifeboat         Dan Callahan
# 9945                  Lifeboat           Jay Antani
#
#                        publisher rating          date  \
# 3               Hartford Courant  3.5/4   Mar 4, 2024
# 6     Seattle Post-Intelligencer  2.5/4   Mar 4, 2024
# 9                Chicago Tribune  3.5/4   Mar 4, 2024
# 12                  Buffalo News    4/5   Mar 4, 2024
# 14                       Newsday    3/4   Mar 4, 2024
# ...                          ...    ...           ...
# 9941              New York Times    4/5  Mar 25, 2006
# 9942       Combustible Celluloid  3.5/4  Dec 17, 2005
# 9943   Arkansas Democrat-Gazette    3/5   Nov 7, 2005
# 9944              Slant Magazine    4/4  Oct 24, 2005
# 9945              Filmcritic.com    4/5  Oct 21, 2005
#
#                                                 comment
# 3     Next to Stand By Me, The Shawshank Redemption ...
# 6     The acting is so strong, so seductive in The S...
# 9     The Shawshank Redemption may be working with s...
# 12    It's a movie with dignity and surprises and be...
# 14    You've never seen a prison movie quite like it...
# ...                                                 ...
# 9941  That old master of screen melodrama, Alfred Hi...
# 9942                    It's a technical tour-de-force.
# 9943
# 9944  Hitchcock's shifting sympathies guarantee our ...
# 9945  boasts the filmmaker's trademark technical pol...
#
# [5508 rows x 6 columns]

# %%
comment_nan_count = new_df['comment'].isna().sum()
print(comment_nan_count)
# Out:
# 0

# %%
new_df.to_csv('reviews.csv', encoding='utf-8', index=False)

# %%
filtered_ratings = new_df[new_df['rating'].str.contains(r'\d*\.?\d*\/\d*')]
new_ratings = list()
for rating in filtered_ratings['rating']:
    split_rate = rating.replace(' ' , '').split('/')
    numerator = split_rate[0]
    denominator = split_rate[1]
    new_ratings.append((float(numerator)/float(denominator))*10)

filtered_ratings['rating'] = new_ratings

display(filtered_ratings)
# Out:
# /var/folders/gn/rwqf62cs4pl5pphc7_b6ksvh0000gn/T/ipykernel_36444/1408801279.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_ratings['rating'] = new_ratings
#                     movie_name          critic_name  \
# 3     The Shawshank Redemption      Malcolm Johnson
# 6     The Shawshank Redemption       William Arnold
# 9     The Shawshank Redemption   Michael Wilmington
# 12    The Shawshank Redemption           Jeff Simon
# 14    The Shawshank Redemption         Jack Mathews
# ...                        ...                  ...
# 9941                  Lifeboat      Bosley Crowther
# 9942                  Lifeboat  Jeffrey M. Anderson
# 9943                  Lifeboat        Philip Martin
# 9944                  Lifeboat         Dan Callahan
# 9945                  Lifeboat           Jay Antani
#
#                        publisher  rating          date  \
# 3               Hartford Courant    8.75   Mar 4, 2024
# 6     Seattle Post-Intelligencer    6.25   Mar 4, 2024
# 9                Chicago Tribune    8.75   Mar 4, 2024
# 12                  Buffalo News    8.00   Mar 4, 2024
# 14                       Newsday    7.50   Mar 4, 2024
# ...                          ...     ...           ...
# 9941              New York Times    8.00  Mar 25, 2006
# 9942       Combustible Celluloid    8.75  Dec 17, 2005
# 9943   Arkansas Democrat-Gazette    6.00   Nov 7, 2005
# 9944              Slant Magazine   10.00  Oct 24, 2005
# 9945              Filmcritic.com    8.00  Oct 21, 2005
#
#                                                 comment
# 3     Next to Stand By Me, The Shawshank Redemption ...
# 6     The acting is so strong, so seductive in The S...
# 9     The Shawshank Redemption may be working with s...
# 12    It's a movie with dignity and surprises and be...
# 14    You've never seen a prison movie quite like it...
# ...                                                 ...
# 9941  That old master of screen melodrama, Alfred Hi...
# 9942                    It's a technical tour-de-force.
# 9943
# 9944  Hitchcock's shifting sympathies guarantee our ...
# 9945  boasts the filmmaker's trademark technical pol...
#
# [4778 rows x 6 columns]

# %%
final_df = filtered_ratings
month_map = {month: index for index, month in enumerate(calendar.month_abbr) if month}
date_list = list()
for date in final_df['date']:
    split_date = date.split(' ')
    year = split_date[2]
    day = split_date[1].replace(',','')
    month = month_map[split_date[0]]
    date_str = str(year) + '-' + str(month) + '-' + str(day)
    date_list.append(date_str)

final_df['date'] = date_list
# Out:
# /var/folders/gn/rwqf62cs4pl5pphc7_b6ksvh0000gn/T/ipykernel_36444/578989524.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['date'] = date_list

# %%
final_df.to_csv('reviews.csv', encoding='utf-8', index=False)
